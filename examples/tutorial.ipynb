# %% [markdown]
# <a href="https://colab.research.google.com/github/simbakm/simbakm/blob/main/examples/tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#   <a href="https://ultralytics.com/yolo" target="_blank">
#     <img width="1024" src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov8/banner-yolov8.png">
#   </a>
#
#   [中文](https://docs.ultralytics.com/zh/) | [한국어](https://docs.ultralytics.com/ko/) | [日本語](https://docs.ultralytics.com/ja/) | [Русский](https://docs.ultralytics.com/ru/) | [Deutsch](https://docs.ultralytics.com/de/) | [Français](https://docs.ultralytics.com/fr/) | [Español](https://docs.ultralytics.com/es/) | [Português](https://docs.ultralytics.com/pt/) | [Türkçe](https://docs.ultralytics.com/tr/) | [Tiếng Việt](https://docs.ultralytics.com/vi/) | [العربية](https://docs.ultralytics.com/ar/)
#
#   <a href="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yml"><img src="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yml/badge.svg" alt="Ultralytics CI"></a>
#   <a href="https://console.paperspace.com/github/ultralytics/ultralytics"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run on Gradient"/></a>
#   <a href="https://colab.research.google.com/github/ultralytics/ultralytics/blob/main/examples/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#   <a href="https://www.kaggle.com/models/ultralytics/yolo11"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
#
#   <a href="https://ultralytics.com/discord"><img alt="Discord" src="https://img.shields.io/discord/1089800235347353640?logo=discord&logoColor=white&label=Discord&color=blue"></a>
#   <a href="https://community.ultralytics.com"><img alt="Ultralytics Forums" src="https://img.shields.io/discourse/users?server=https%3A%2F%2Fcommunity.ultralytics.com&logo=discourse&label=Forums&color=blue"></a>
#   <a href="https://reddit.com/r/ultralytics"><img alt="Ultralytics Reddit" src="https://img.shields.io/reddit/subreddit-subscribers/ultralytics?style=flat&logo=reddit&logoColor=white&label=Reddit&color=blue"></a>
# </div>
#
# This **Ultralytics Colab Notebook** is the easiest way to get started with [YOLO models](https://www.ultralytics.com/yolo)—no installation needed. Built by [Ultralytics](https://www.ultralytics.com/), the creators of YOLO, this notebook walks you through running **state-of-the-art** models directly in your browser.
#
# Ultralytics models are constantly updated for performance and flexibility. They're **fast**, **accurate**, and **easy to use**, and they excel at [object detection](https://docs.ultralytics.com/tasks/detect/), [tracking](https://docs.ultralytics.com/modes/track/), [instance segmentation](https://docs.ultralytics.com/tasks/segment/), [image classification](https://docs.ultralytics.com/tasks/classify/), and [pose estimation](https://docs.ultralytics.com/tasks/pose/).
#
# Find detailed documentation in the [Ultralytics Docs](https://docs.ultralytics.com/). Get support via [GitHub Issues](https://github.com/ultralytics/ultralytics/issues/new/choose). Join discussions on [Discord](https://discord.com/invite/ultralytics), [Reddit](https://www.reddit.com/r/ultralytics/), and the [Ultralytics Community Forums](https://community.ultralytics.com/)!
#
# Request an Enterprise License for commercial use at [Ultralytics Licensing](https://www.ultralytics.com/license).
#
# <br>
# <div>
#   <a href="https://www.youtube.com/watch?v=ZN3nRZT7b24" target="_blank">
#     <img src="https://img.youtube.com/vi/ZN3nRZT7b24/maxresdefault.jpg" alt="Ultralytics Video" width="640" style="border-radius: 10px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);">
#   </a>
#
#   <p style="font-size: 16px; font-family: Arial, sans-serif; color: #555;">
#     <strong>Watch: </strong> How to Train
#     <a href="https://github.com/ultralytics/ultralytics">Ultralytics</a>
#     <a href="https://docs.ultralytics.com/models/yolo11/">YOLO11</a> Model on Custom Dataset using Google Colab Notebook 🚀
#   </p>
# </div>

# %% [markdown]
# # Setup
#
# pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.
#
# [![PyPI - Version](https://img.shields.io/pypi/v/ultralytics?logo=pypi&logoColor=white)](https://pypi.org/project/ultralytics/) [![Downloads](https://static.pepy.tech/badge/ultralytics)](https://clickpy.clickhouse.com/dashboard/ultralytics) [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/ultralytics?logo=python&logoColor=gold)](https://pypi.org/project/ultralytics/)

# %%
# !uv pip install ultralytics
# !pip install roboflow kagglehub
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.233 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.3/112.6 GB disk)

# %% [markdown]
# **STEP 2 — Download the Roboflow dataset (YOLOv11-ready)bold text**

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="YdrZFjwWblcZBkXrqqaR")
project = rf.workspace("stairs-ttqqp").project("trash-bin-asn0s")
dataset = project.version(1).download("yolov11")

roboflow_path = dataset.location
print("Roboflow dataset:", roboflow_path)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in trash-bin-1 to yolov11:: 100%|██████████| 21999/21999 [00:02<00:00, 8266.00it/s]
# Extracting Dataset Version Zip to trash-bin-1 in yolov11:: 100%|██████████| 902/902 [00:00<00:00, 8306.92it/s]
# Roboflow dataset: /content/trash-bin-1

# %% [markdown]
# ## **STEP 3: Download the TACO dataset from KaggleHub**

# %%
import kagglehub
path = kagglehub.dataset_download("kneroma/tacotrashdataset")
print("Downloaded to:", path)
# Out:
# Using Colab cache for faster access to the 'tacotrashdataset' dataset.
# Downloaded to: /kaggle/input/tacotrashdataset

# %% [markdown]
# **STEP 4 — Convert TACO (COCO JSON) → YOLO format**

# %%
import json, os, shutil
from glob import glob
from tqdm import tqdm

# TACO dataset path (from KaggleHub)
taco_path = "/kaggle/input/tacotrashdataset"
data_dir = os.path.join(taco_path, "data")

# Load annotations
annotations_path = os.path.join(data_dir, "annotations.json")
annotations = json.load(open(annotations_path))

# Output
output_taco = "/content/taco_yolo"
#delete privous derectories
if os.path.exists(output_taco):
    shutil.rmtree(output_taco)
    print("Old taco_yolo directory removed.")
else:
    print("No previous taco_yolo folder found.")

os.makedirs(f"{output_taco}/images", exist_ok=True)
os.makedirs(f"{output_taco}/labels", exist_ok=True)

# Map image id → image info
image_map = {img["id"]: img for img in annotations["images"]}

# Find all images recursively
all_images = {}
image_files = glob(f"{data_dir}/**/*.jpg", recursive=True) + \
              glob(f"{data_dir}/**/*.JPG", recursive=True)

for f in image_files:
    all_images[os.path.relpath(f, data_dir)] = f


print("Total images found:", len(all_images))

# Group annotations by image ID
ann_by_image = {}
for ann in annotations["annotations"]:
    img_id = ann["image_id"]
    ann_by_image.setdefault(img_id, []).append(ann)

# Convert to YOLO
for img_id, img_info in tqdm(image_map.items()):
    filename = img_info["file_name"]
    batch_relative_path = filename  # contains batch_x/000000.jpg

    if batch_relative_path not in all_images:
        print("Missing image:", batch_relative_path)
        continue

    src = all_images[batch_relative_path]

    # create unique new filename based on img_id
    new_name = f"{img_id}.jpg"
    dst = f"{output_taco}/images/{new_name}"

    shutil.copy(src, dst)

    # image width/height
    W = img_info["width"]
    H = img_info["height"]

    # label path (same name as image)
    label_path = f"{output_taco}/labels/{img_id}.txt"
    with open(label_path, "w") as f:
        for ann in ann_by_image.get(img_id, []):
            x, y, w, h = ann["bbox"]

            # convert to YOLO
            xc = (x + w/2) / W
            yc = (y + h/2) / H
            w /= W
            h /= H

            class_id = ann["category_id"]
            f.write(f"{class_id} {xc} {yc} {w} {h}\n")

print("DONE — TACO converted to YOLO:", output_taco)
# Out:
# No previous taco_yolo folder found.
# Total images found: 1500
# 100%|██████████| 1500/1500 [00:34<00:00, 43.35it/s]
# DONE — TACO converted to YOLO: /content/taco_yolo

# %% [markdown]
# # **5: Split the dataset into Train,val and test using ratio 80|10|10**

# %%
import os, random, shutil
from glob import glob

taco_img = "/content/taco_yolo/images"
taco_lbl = "/content/taco_yolo/labels"

images = sorted(glob(f"{taco_img}/*.jpg"))
random.shuffle(images)

n = len(images)
train_split = int(n * 0.8)
val_split = int(n * 0.9)

train_files = images[:train_split]
val_files   = images[train_split:val_split]
test_files  = images[val_split:]

def copy_split(files, folder):
    os.makedirs(f"/content/taco_split/images/{folder}", exist_ok=True)
    os.makedirs(f"/content/taco_split/labels/{folder}", exist_ok=True)
    for img in files:
        lbl = img.replace("images", "labels").replace(".jpg", ".txt")
        shutil.copy(img, f"/content/taco_split/images/{folder}/")
        shutil.copy(lbl, f"/content/taco_split/labels/{folder}/")

copy_split(train_files, "train")
copy_split(val_files, "val")
copy_split(test_files, "test")

print("TACO split complete!")
# Out:
# TACO split complete!

# %% [markdown]
# **STEP 6 — Create a combined dataset**

# %%
# remove old combined folder
shutil.rmtree("/content/combined", ignore_errors=True)

# create combined structure
for split in ["train", "val", "test"]:
    os.makedirs(f"/content/combined/images/{split}", exist_ok=True)
    os.makedirs(f"/content/combined/labels/{split}", exist_ok=True)

# copy TACO train/val/test
# !cp -r /content/taco_split/images/train/* /content/combined/images/train/
# !cp -r /content/taco_split/labels/train/* /content/combined/labels/train/

# !cp -r /content/taco_split/images/val/* /content/combined/images/val/
# !cp -r /content/taco_split/labels/val/* /content/combined/labels/val/

# !cp -r /content/taco_split/images/test/* /content/combined/images/test/
# !cp -r /content/taco_split/labels/test/* /content/combined/labels/test/

# copy roboflow
# train
# !cp -r $roboflow_path/train/images/* /content/combined/images/train/
# !cp -r $roboflow_path/train/labels/* /content/combined/labels/train/

# val
# !cp -r $roboflow_path/valid/images/* /content/combined/images/val/
# !cp -r $roboflow_path/valid/labels/* /content/combined/labels/val/

# test
# !cp -r $roboflow_path/test/images/* /content/combined/images/test/
# !cp -r $roboflow_path/test/labels/* /content/combined/labels/test/

# %% [markdown]
# **step7: Create YOLO data.yaml**

# %%
data_yaml = """
train: /content/combined/images/train
val: /content/combined/images/val
test: /content/combined/images/test

nc: 1
names: ["trash_bin"]
"""
open("combined.yaml", "w").write(data_yaml)

print("combined.yaml created.")
# Out:
# combined.yaml created.

# %% [markdown]
# # **8: — Train YOLOv11**

# %%
# !yolo train model=yolo11n.pt data=combined.yaml epochs=40 imgsz=640
# Out:
# Ultralytics 8.3.233 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=combined.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=40, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,035 parameters, 2,590,019 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1704.5±1462.7 MB/s, size: 1500.5 KB)
# train: Scanning /content/combined/labels/train.cache... 1514 images, 0 backgrounds, 1192 corrupt: 100% ━━━━━━━━━━━━ 1514/1514 20.5Mit/s 0.0s
# train: /content/combined/images/train/1.jpg: ignoring corrupt image/label: Label class 18 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/10.jpg: ignoring corrupt image/label: Label class 39 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/100.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1000.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1001.jpg: ignoring corrupt image/label: Label class 55 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1003.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1004.jpg: ignoring corrupt image/label: Label class 55 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1005.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1006.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1007.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1008.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1009.jpg: ignoring corrupt image/label: Label class 36 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1010.jpg: ignoring corrupt image/label: Label class 57 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1012.jpg: ignoring corrupt image/label: Label class 36 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1013.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1014.jpg: ignoring corrupt image/label: Label class 36 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1015.jpg: ignoring corrupt image/label: Label class 36 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1016.jpg: ignoring corrupt image/label: Label class 33 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1017.jpg: ignoring corrupt image/label: Label class 22 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1018.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1019.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/102.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1020.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1021.jpg: ignoring corrupt image/label: Label class 50 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1022.jpg: ignoring corrupt image/label: Label class 20 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1023.jpg: ignoring corrupt image/label: Label class 39 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1025.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1026.jpg: ignoring corrupt image/label: Label class 55 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1028.jpg: ignoring corrupt image/label: Label class 50 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1029.jpg: ignoring corrupt image/label: Label class 50 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1030.jpg: ignoring corrupt image/label: Label class 12 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1032.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1033.jpg: ignoring corrupt image/label: Label class 50 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1035.jpg: ignoring corrupt image/label: Label class 48 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1036.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1037.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1038.jpg: ignoring corrupt image/label: Label class 36 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1039.jpg: ignoring corrupt image/label: Label class 40 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1041.jpg: ignoring corrupt image/label: Label class 34 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1042.jpg: ignoring corrupt image/label: Label class 21 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1043.jpg: ignoring corrupt image/label: Label class 21 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1044.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1045.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1046.jpg: ignoring corrupt image/label: Label class 55 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1048.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1049.jpg: ignoring corrupt image/label: Label class 39 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/105.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1050.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1051.jpg: ignoring corrupt image/label: Label class 27 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1052.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1053.jpg: ignoring corrupt image/label: Label class 48 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1054.jpg: ignoring corrupt image/label: Label class 57 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1055.jpg: ignoring corrupt image/label: Label class 27 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1056.jpg: ignoring corrupt image/label: Label class 55 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1057.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1058.jpg: ignoring corrupt image/label: Label class 29 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1059.jpg: ignoring corrupt image/label: Label class 42 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/106.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1060.jpg: ignoring corrupt image/label: Label class 45 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1061.jpg: ignoring corrupt image/label: Label class 10 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1062.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1063.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1064.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1065.jpg: ignoring corrupt image/label: Label class 36 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1066.jpg: ignoring corrupt image/label: Label class 50 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1067.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1069.jpg: ignoring corrupt image/label: Label class 55 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/107.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1070.jpg: ignoring corrupt image/label: Label class 27 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1071.jpg: ignoring corrupt image/label: Label class 43 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1072.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1073.jpg: ignoring corrupt image/label: Label class 42 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1074.jpg: ignoring corrupt image/label: Label class 21 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1075.jpg: ignoring corrupt image/label: Label class 36 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1076.jpg: ignoring corrupt image/label: Label class 21 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1077.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1079.jpg: ignoring corrupt image/label: Label class 40 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/108.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1080.jpg: ignoring corrupt image/label: Label class 39 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1081.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1082.jpg: ignoring corrupt image/label: Label class 50 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1085.jpg: ignoring corrupt image/label: Label class 14 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1087.jpg: ignoring corrupt image/label: Label class 36 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1088.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1089.jpg: ignoring corrupt image/label: Label class 55 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/109.jpg: ignoring corrupt image/label: Label class 36 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1091.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1094.jpg: ignoring corrupt image/label: Label class 39 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1096.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1097.jpg: ignoring corrupt image/label: Label class 29 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1098.jpg: ignoring corrupt image/label: Label class 36 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1099.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/11.jpg: ignoring corrupt image/label: Label class 57 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/110.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1100.jpg: ignoring corrupt image/label: Label class 51 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1101.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1102.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1103.jpg: ignoring corrupt image/label: Label class 20 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1105.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1106.jpg: ignoring corrupt image/label: Label class 52 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1107.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1109.jpg: ignoring corrupt image/label: Label class 44 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/111.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1110.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1111.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1112.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1114.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1115.jpg: ignoring corrupt image/label: Label class 46 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1117.jpg: ignoring corrupt image/label: Label class 45 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1118.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1119.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/112.jpg: ignoring corrupt image/label: Label class 42 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1120.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1121.jpg: ignoring corrupt image/label: Label class 16 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1123.jpg: ignoring corrupt image/label: Label class 50 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1124.jpg: ignoring corrupt image/label: Label class 46 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1126.jpg: ignoring corrupt image/label: Label class 21 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1127.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1128.jpg: ignoring corrupt image/label: Label class 29 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1129.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/113.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1130.jpg: ignoring corrupt image/label: Label class 45 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1133.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1136.jpg: ignoring corrupt image/label: Label class 34 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1137.jpg: ignoring corrupt image/label: Label class 12 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1139.jpg: ignoring corrupt image/label: Label class 36 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/114.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1141.jpg: ignoring corrupt image/label: Label class 12 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1143.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1144.jpg: ignoring corrupt image/label: Label class 55 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1145.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1146.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1149.jpg: ignoring corrupt image/label: Label class 21 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/115.jpg: ignoring corrupt image/label: Label class 31 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1150.jpg: ignoring corrupt image/label: Label class 36 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1151.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1152.jpg: ignoring corrupt image/label: Label class 55 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1153.jpg: ignoring corrupt image/label: Label class 16 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1155.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1159.jpg: ignoring corrupt image/label: Label class 18 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/116.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1161.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1162.jpg: ignoring corrupt image/label: Label class 42 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1163.jpg: ignoring corrupt image/label: Label class 49 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1164.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1165.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1166.jpg: ignoring corrupt image/label: Label class 20 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1167.jpg: ignoring corrupt image/label: Label class 36 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1168.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1169.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/117.jpg: ignoring corrupt image/label: Label class 36 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1170.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1171.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1172.jpg: ignoring corrupt image/label: Label class 49 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1174.jpg: ignoring corrupt image/label: Label class 55 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1175.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1176.jpg: ignoring corrupt image/label: Label class 8 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1177.jpg: ignoring corrupt image/label: Label class 39 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1178.jpg: ignoring corrupt image/label: Label class 36 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1179.jpg: ignoring corrupt image/label: Label class 29 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/118.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1180.jpg: ignoring corrupt image/label: Label class 49 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1181.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1182.jpg: ignoring corrupt image/label: Label class 12 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1183.jpg: ignoring corrupt image/label: Label class 36 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1184.jpg: ignoring corrupt image/label: Label class 30 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1186.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1187.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1188.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1189.jpg: ignoring corrupt image/label: Label class 57 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1190.jpg: ignoring corrupt image/label: Label class 45 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1191.jpg: ignoring corrupt image/label: Label class 57 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1192.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1193.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1194.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1195.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1196.jpg: ignoring corrupt image/label: Label class 50 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1197.jpg: ignoring corrupt image/label: Label class 31 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1198.jpg: ignoring corrupt image/label: Label class 21 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1199.jpg: ignoring corrupt image/label: Label class 27 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/12.jpg: ignoring corrupt image/label: Label class 16 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/120.jpg: ignoring corrupt image/label: Label class 33 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1200.jpg: ignoring corrupt image/label: Label class 21 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1201.jpg: ignoring corrupt image/label: Label class 8 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1202.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1203.jpg: ignoring corrupt image/label: Label class 55 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1204.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1205.jpg: ignoring corrupt image/label: Label class 55 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1206.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1207.jpg: ignoring corrupt image/label: Label class 16 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1208.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1209.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/121.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1211.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1212.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1214.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1215.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1216.jpg: ignoring corrupt image/label: Label class 29 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1217.jpg: ignoring corrupt image/label: Label class 49 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1219.jpg: ignoring corrupt image/label: Label class 36 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/122.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1220.jpg: ignoring corrupt image/label: Label class 43 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1221.jpg: ignoring corrupt image/label: Label class 21 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1222.jpg: ignoring corrupt image/label: Label class 33 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1223.jpg: ignoring corrupt image/label: Label class 39 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1224.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1226.jpg: ignoring corrupt image/label: Label class 39 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1227.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1228.jpg: ignoring corrupt image/label: Label class 45 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1229.jpg: ignoring corrupt image/label: Label class 36 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/123.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1231.jpg: ignoring corrupt image/label: Label class 36 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1232.jpg: ignoring corrupt image/label: Label class 55 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1233.jpg: ignoring corrupt image/label: Label class 40 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1234.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1235.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1237.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1238.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1239.jpg: ignoring corrupt image/label: Label class 55 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1240.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1241.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1243.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1247.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1248.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1249.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/125.jpg: ignoring corrupt image/label: Label class 53 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1250.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1251.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1252.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1253.jpg: ignoring corrupt image/label: Label class 50 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1254.jpg: ignoring corrupt image/label: Label class 21 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1255.jpg: ignoring corrupt image/label: Label class 20 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1256.jpg: ignoring corrupt image/label: Label class 12 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1257.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1258.jpg: ignoring corrupt image/label: Label class 51 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1259.jpg: ignoring corrupt image/label: Label class 29 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/126.jpg: ignoring corrupt image/label: Label class 12 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1260.jpg: ignoring corrupt image/label: Label class 29 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1261.jpg: ignoring corrupt image/label: Label class 29 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1262.jpg: ignoring corrupt image/label: Label class 29 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1265.jpg: ignoring corrupt image/label: Label class 29 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1267.jpg: ignoring corrupt image/label: Label class 36 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1268.jpg: ignoring corrupt image/label: Label class 57 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1269.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1270.jpg: ignoring corrupt image/label: Label class 21 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1271.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1272.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1273.jpg: ignoring corrupt image/label: Label class 50 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1274.jpg: ignoring corrupt image/label: Label class 57 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1275.jpg: ignoring corrupt image/label: Label class 57 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1276.jpg: ignoring corrupt image/label: Label class 12 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1277.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1278.jpg: ignoring corrupt image/label: Label class 57 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1279.jpg: ignoring corrupt image/label: Label class 36 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/128.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1280.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1281.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1282.jpg: ignoring corrupt image/label: Label class 39 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1283.jpg: ignoring corrupt image/label: Label class 57 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1284.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1285.jpg: ignoring corrupt image/label: Label class 57 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1286.jpg: ignoring corrupt image/label: Label class 36 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1287.jpg: ignoring corrupt image/label: Label class 57 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1289.jpg: ignoring corrupt image/label: Label class 29 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/129.jpg: ignoring corrupt image/label: Label class 29 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1292.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1294.jpg: ignoring corrupt image/label: Label class 29 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1298.jpg: ignoring corrupt image/label: Label class 39 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1299.jpg: ignoring corrupt image/label: Label class 57 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/13.jpg: ignoring corrupt image/label: Label class 45 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/130.jpg: ignoring corrupt image/label: Label class 52 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1300.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1303.jpg: ignoring corrupt image/label: Label class 39 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1305.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1306.jpg: ignoring corrupt image/label: Label class 20 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1307.jpg: ignoring corrupt image/label: Label class 7 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1308.jpg: ignoring corrupt image/label: Label class 59 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/1309.jpg: ignoring corrupt image/label: Label class 50 exceeds dataset class count 1. Possible class labels are 0-0
# train: /content/combined/images/train/131.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 1. Possible class labels are 0-0
# ...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.6it/s 1.5s
#                    all        107        142       0.47      0.373      0.374      0.167
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/40      2.69G       1.06      1.495      1.428          6        640: 100% ━━━━━━━━━━━━ 21/21 3.7it/s 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.6it/s 1.1s
#                    all        107        142      0.411      0.462      0.448      0.224
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/40      2.71G      1.004      1.439      1.399          2        640: 100% ━━━━━━━━━━━━ 21/21 3.7it/s 5.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.2it/s 1.8s
#                    all        107        142      0.478      0.401      0.374      0.214
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/40      2.72G     0.9911      1.346       1.37         10        640: 100% ━━━━━━━━━━━━ 21/21 4.0it/s 5.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.6it/s 1.1s
#                    all        107        142        0.5      0.493      0.477       0.27
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/40      2.73G     0.9471       1.26      1.348          3        640: 100% ━━━━━━━━━━━━ 21/21 3.5it/s 6.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.2it/s 1.3s
#                    all        107        142      0.584      0.521      0.486      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/40      2.73G     0.9796      1.201      1.365          7        640: 100% ━━━━━━━━━━━━ 21/21 4.0it/s 5.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.7it/s 1.1s
#                    all        107        142      0.613      0.704      0.702      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/40      2.75G     0.9263      1.171      1.333          8        640: 100% ━━━━━━━━━━━━ 21/21 3.4it/s 6.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.3it/s 1.2s
#                    all        107        142      0.699      0.648      0.729      0.454
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/40      2.76G      1.015      1.212      1.396          7        640: 100% ━━━━━━━━━━━━ 21/21 4.3it/s 4.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.9it/s 1.4s
#                    all        107        142      0.654       0.57      0.647      0.406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/40      2.76G     0.8893      1.135      1.314          3        640: 100% ━━━━━━━━━━━━ 21/21 3.2it/s 6.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 4.5it/s 0.9s
#                    all        107        142      0.631      0.725      0.717      0.473
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/40      2.76G     0.8868      1.027      1.291          7        640: 100% ━━━━━━━━━━━━ 21/21 3.5it/s 6.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.7it/s 2.3s
#                    all        107        142      0.674      0.746      0.763      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/40      2.76G      0.852      1.112      1.293          2        640: 100% ━━━━━━━━━━━━ 21/21 3.8it/s 5.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.9it/s 1.0s
#                    all        107        142      0.789      0.739      0.806      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/40      2.76G      0.842      1.026      1.276          5        640: 100% ━━━━━━━━━━━━ 21/21 3.7it/s 5.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.3it/s 1.8s
#                    all        107        142      0.769      0.655      0.751      0.538
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/40      2.76G     0.8582     0.9707       1.29          5        640: 100% ━━━━━━━━━━━━ 21/21 4.0it/s 5.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.9it/s 1.0s
#                    all        107        142      0.752       0.64      0.753      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/40      2.76G     0.8011     0.9604      1.239          6        640: 100% ━━━━━━━━━━━━ 21/21 3.5it/s 6.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.9it/s 1.4s
#                    all        107        142      0.829      0.746      0.848      0.608
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/40      2.76G     0.8406     0.9113      1.271          8        640: 100% ━━━━━━━━━━━━ 21/21 4.0it/s 5.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.2it/s 1.3s
#                    all        107        142      0.792      0.768      0.848      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/40      2.76G     0.8031     0.8896      1.305          3        640: 100% ━━━━━━━━━━━━ 21/21 3.3it/s 6.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 4.2it/s 1.0s
#                    all        107        142      0.784      0.816      0.857      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/40      2.76G     0.8104       0.86      1.233          4        640: 100% ━━━━━━━━━━━━ 21/21 3.9it/s 5.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 4.2it/s 0.9s
#                    all        107        142       0.75      0.783      0.809      0.577
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/40      2.76G     0.7918     0.8752      1.243          3        640: 100% ━━━━━━━━━━━━ 21/21 3.3it/s 6.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.3it/s 1.2s
#                    all        107        142      0.802      0.754      0.846      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/40      2.76G     0.7543     0.8141      1.211          4        640: 100% ━━━━━━━━━━━━ 21/21 4.2it/s 5.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.2it/s 1.8s
#                    all        107        142      0.835      0.784      0.866      0.659
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/40      2.76G     0.7929     0.8181      1.242          3        640: 100% ━━━━━━━━━━━━ 21/21 3.8it/s 5.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 4.6it/s 0.9s
#                    all        107        142      0.834      0.816      0.875      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/40      2.76G     0.7685     0.8044      1.212          7        640: 100% ━━━━━━━━━━━━ 21/21 3.5it/s 6.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.7it/s 1.5s
#                    all        107        142      0.906      0.817      0.899        0.7
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/40      2.76G     0.7415     0.7797      1.204          5        640: 100% ━━━━━━━━━━━━ 21/21 4.0it/s 5.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.6it/s 1.1s
#                    all        107        142      0.864      0.761      0.874       0.69
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/40      2.76G     0.7279     0.7632      1.188          8        640: 100% ━━━━━━━━━━━━ 21/21 3.3it/s 6.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.1s
#                    all        107        142      0.878       0.81      0.896      0.678
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/40      2.76G     0.6936     0.7524      1.166          9        640: 100% ━━━━━━━━━━━━ 21/21 4.0it/s 5.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.7it/s 1.1s
#                    all        107        142      0.895      0.824       0.91      0.692
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/40      2.76G     0.7258     0.7571      1.186          6        640: 100% ━━━━━━━━━━━━ 21/21 3.4it/s 6.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.7it/s 1.1s
#                    all        107        142      0.935      0.807      0.912      0.713
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/40      2.76G      0.695     0.7215      1.161          5        640: 100% ━━━━━━━━━━━━ 21/21 4.1it/s 5.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.1s
#                    all        107        142      0.864      0.845      0.903      0.715
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/40      2.76G     0.6774     0.7076      1.138         12        640: 100% ━━━━━━━━━━━━ 21/21 3.4it/s 6.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.2s
#                    all        107        142      0.882      0.866      0.921      0.723
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/40      2.76G     0.5501     0.6988      1.072          2        640: 100% ━━━━━━━━━━━━ 21/21 2.8it/s 7.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.9it/s 2.1s
#                    all        107        142      0.918      0.775        0.9      0.702
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/40      2.76G     0.5148     0.6218      1.073          3        640: 100% ━━━━━━━━━━━━ 21/21 4.1it/s 5.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.8it/s 1.0s
#                    all        107        142      0.897      0.797      0.893      0.723
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/40      2.76G      0.506     0.6104      1.092          2        640: 100% ━━━━━━━━━━━━ 21/21 3.4it/s 6.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 4.0it/s 1.0s
#                    all        107        142      0.893      0.825      0.914      0.704
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/40      2.76G     0.5026     0.5732      1.049          2        640: 100% ━━━━━━━━━━━━ 21/21 4.2it/s 5.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.2it/s 1.3s
#                    all        107        142      0.881      0.883      0.933      0.754
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/40      2.76G     0.4643     0.5434      1.042          2        640: 100% ━━━━━━━━━━━━ 21/21 3.5it/s 6.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.8it/s 1.1s
#                    all        107        142      0.913      0.885      0.938      0.769
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/40      2.76G      0.472     0.5213      1.028          3        640: 100% ━━━━━━━━━━━━ 21/21 4.1it/s 5.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.9it/s 1.0s
#                    all        107        142      0.927      0.859      0.928      0.763
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/40      2.76G     0.4442     0.5023      1.001          2        640: 100% ━━━━━━━━━━━━ 21/21 3.4it/s 6.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 4.0it/s 1.0s
#                    all        107        142      0.965      0.838      0.938       0.76
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/40      2.76G      0.438     0.4956     0.9856          2        640: 100% ━━━━━━━━━━━━ 21/21 4.2it/s 5.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.6it/s 1.1s
#                    all        107        142      0.968      0.839      0.939      0.761
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/40      2.76G      0.449     0.4914       1.02          2        640: 100% ━━━━━━━━━━━━ 21/21 3.5it/s 6.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 4.2it/s 1.0s
#                    all        107        142      0.967      0.828      0.934      0.771
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/40      2.76G     0.4355     0.4612     0.9953          2        640: 100% ━━━━━━━━━━━━ 21/21 3.9it/s 5.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.7it/s 1.5s
#                    all        107        142      0.957      0.845      0.937      0.775
#
# 40 epochs completed in 0.088 hours.
# Optimizer stripped from /content/runs/detect/train2/weights/last.pt, 5.5MB
# Optimizer stripped from /content/runs/detect/train2/weights/best.pt, 5.5MB
#
# Validating /content/runs/detect/train2/weights/best.pt...
# Ultralytics 8.3.233 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.7it/s 2.3s
#                    all        107        142      0.958      0.845      0.937      0.774
# Speed: 0.3ms preprocess, 5.1ms inference, 0.0ms loss, 6.0ms postprocess per image
# Results saved to /content/runs/detect/train2
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# ## **STEP 6 — Download trained model**

# %%
from google.colab import files
files.download("/content/runs/detect/train2/weights/best.pt")

# %% [markdown]
# # 1. Predict
#
# YOLO11 may be used directly in the Command Line Interface (CLI) with a `yolo` command for a variety of tasks and modes and accepts additional arguments, i.e. `imgsz=640`. See a full list of available `yolo` [arguments](https://docs.ultralytics.com/usage/cfg/) and other details in the [YOLO11 Predict Docs](https://docs.ultralytics.com/modes/train/).

# %%
# Run inference on an image with YOLO11n
# !yolo predict model=yolo11n.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4/5.4MB 67.5MB/s 0.1s
# Ultralytics 8.3.187 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# Downloading https://ultralytics.com/images/zidane.jpg to 'zidane.jpg': 100% ━━━━━━━━━━━━ 49.2/49.2KB 5.9MB/s 0.0s
# image 1/1 /content/zidane.jpg: 384x640 2 persons, 1 tie, 68.9ms
# Speed: 13.1ms preprocess, 68.9ms inference, 250.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/212889447-69e5bdf1-5800-4e29-835e-2ed2336dede2.jpg" width="600">

# %% [markdown]
# # 2. Val
# Validate a model's accuracy on the [COCO](https://docs.ultralytics.com/datasets/detect/coco/) dataset's `val` or `test` splits. The latest YOLO11 [models](https://github.com/ultralytics/ultralytics#models) are downloaded automatically the first time they are used. See [YOLO11 Val Docs](https://docs.ultralytics.com/modes/val/) for more information.

# %%
# Download COCO val
from ultralytics.utils.downloads import download

download('https://ultralytics.com/assets/coco2017val.zip', unzip=True, dir='datasets') # download (780MB - 5000 images)

# %%
# Validate YOLO11n on COCO8 val
# !yolo val model=yolo11n.pt data=coco8.yaml
# Out:
# Ultralytics 8.3.187 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# WARNING ⚠️ Dataset 'coco8.yaml' images not found, missing path '/content/datasets/coco8/images/val'
# Downloading https://ultralytics.com/assets/coco8.zip to '/content/datasets/coco8.zip': 100% ━━━━━━━━━━━━ 432.8/432.8KB 12.2MB/s 0.0s
# Unzipping /content/datasets/coco8.zip to /content/datasets/coco8...: 100% ━━━━━━━━━━━━ 25/25 4962.5files/s 0.0s
# Dataset download success ✅ (0.6s), saved to /content/datasets
#
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1/755.1KB 22.0MB/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1486.2±504.6 MB/s, size: 54.0 KB)
# val: Scanning /content/datasets/coco8/labels/val... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 118.2it/s 0.0s
# val: New cache created: /content/datasets/coco8/labels/val.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 0.88it/s 1.1s
#                    all          4         17       0.57       0.85      0.847      0.632
#                 person          3         10      0.557        0.6      0.585      0.272
#                    dog          1          1      0.548          1      0.995      0.697
#                  horse          1          2      0.531          1      0.995      0.674
#               elephant          1          2      0.371        0.5      0.516      0.256
#               umbrella          1          1      0.569          1      0.995      0.995
#           potted plant          1          1      0.847          1      0.995      0.895
# Speed: 0.3ms preprocess, 18.1ms inference, 0.0ms loss, 21.1ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# # 3. Train
#
# <p align=""><a href="https://ultralytics.com/hub"><img width="1000" src="https://github.com/ultralytics/assets/raw/main/yolov8/banner-integrations.png"/></a></p>
#
# Train YOLO11 on [Detect](https://docs.ultralytics.com/tasks/detect/), [Segment](https://docs.ultralytics.com/tasks/segment/), [Classify](https://docs.ultralytics.com/tasks/classify/) and [Pose](https://docs.ultralytics.com/tasks/pose/) datasets. See [YOLO11 Train Docs](https://docs.ultralytics.com/modes/train/) for more information.

# %%
#@title Select YOLO11 🚀 logger {run: 'auto'}
logger = 'TensorBoard' #@param ['TensorBoard', 'Weights & Biases']

if logger == 'TensorBoard':
  # !yolo settings tensorboard=True
  # %load_ext tensorboard
  # %tensorboard --logdir .
elif logger == 'Weights & Biases':
  # !yolo settings wandb=True

# %%
# Train YOLO11n on COCO8 for 3 epochs
# !yolo train model=yolo11n.pt data=coco8.yaml epochs=3 imgsz=640
# Out:
# Ultralytics 8.3.187 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=coco8.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=3, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    464912  ultralytics.nn.modules.head.Detect           [80, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,624,080 parameters, 2,624,064 gradients, 6.6 GFLOPs
#
# Transferred 499/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1134.4±454.3 MB/s, size: 50.0 KB)
# train: Scanning /content/datasets/coco8/labels/train... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 1726.9it/s 0.0s
# train: New cache created: /content/datasets/coco8/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 446.6±70.7 MB/s, size: 54.0 KB)
# val: Scanning /content/datasets/coco8/labels/val.cache... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 27458.6it/s 0.0s
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000119, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 3 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/3     0.645G     0.9078       2.63      1.334         29        640: 100% ━━━━━━━━━━━━ 1/1 0.09it/s 11.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 0.30it/s 3.3s
#                    all          4         17      0.592       0.85      0.878      0.634
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/3     0.674G      1.328      3.181      1.625         46        640: 100% ━━━━━━━━━━━━ 1/1 7.7it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 10.6it/s 0.1s
#                    all          4         17      0.584       0.85      0.847      0.631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/3     0.674G     0.9821      3.036      1.326         20        640: 100% ━━━━━━━━━━━━ 1/1 7.9it/s 0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 14.3it/s 0.1s
#                    all          4         17      0.587       0.85      0.851      0.615
#
# 3 epochs completed in 0.004 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 5.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 5.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.187 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 25.5it/s 0.0s
#                    all          4         17      0.592       0.85      0.877      0.633
#                 person          3         10      0.586        0.6      0.585      0.262
#                    dog          1          1      0.554          1      0.995      0.697
#                  horse          1          2      0.616          1      0.995      0.674
#               elephant          1          2      0.373        0.5      0.695      0.275
#               umbrella          1          1      0.573          1      0.995      0.995
#           potted plant          1          1      0.854          1      0.995      0.895
# Speed: 0.3ms preprocess, 4.3ms inference, 0.0ms loss, 1.9ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# # 4. Export
#
# Export a YOLO model to any supported format below with the `format` argument, i.e. `format=onnx`. See [Export Docs](https://docs.ultralytics.com/modes/export/) for more information.
#
# - 💡 ProTip: Export to [ONNX](https://docs.ultralytics.com/integrations/onnx/) or [OpenVINO](https://docs.ultralytics.com/integrations/openvino/) for up to 3x CPU speedup.
# - 💡 ProTip: Export to [TensorRT](https://docs.ultralytics.com/integrations/tensorrt/) for up to 5x GPU speedup.
#
# | Format | `format` Argument | Model | Metadata | Arguments |
# |--------|-----------------|-------|----------|------------|
# | [PyTorch](https://pytorch.org/) | - | `yolo11n.pt` | ✅ | - |
# | [TorchScript](https://docs.ultralytics.com/integrations/torchscript) | `torchscript` | `yolo11n.torchscript` | ✅ | `imgsz`, `batch`, `dynamic`, `optimize`, `half`, `nms`, `device` |
# | [ONNX](https://docs.ultralytics.com/integrations/onnx) | `onnx` | `yolo11n.onnx` | ✅ | `imgsz`, `batch`, `dynamic`, `half`, `opset`, `simplify`, `nms`, `device` |
# | [OpenVINO](https://docs.ultralytics.com/integrations/openvino) | `openvino` | `yolo11n_openvino_model/` | ✅ | `imgsz`, `batch`, `dynamic`, `half`, `int8`, `nms`, `fraction`, `device`, `data` |
# | [TensorRT](https://docs.ultralytics.com/integrations/tensorrt) | `engine` | `yolo11n.engine` | ✅ | `imgsz`, `batch`, `dynamic`, `half`, `int8`, `simplify`, `nms`, `fraction`, `device`, `data`, `workspace` |
# | [CoreML](https://docs.ultralytics.com/integrations/coreml) | `coreml` | `yolo11n.mlpackage` | ✅ | `imgsz`, `batch`, `half`, `int8`, `nms`, `device` |
# | [TF SavedModel](https://docs.ultralytics.com/integrations/tf-savedmodel) | `saved_model` | `yolo11n_saved_model/` | ✅ | `imgsz`, `batch`, `int8`, `keras`, `nms`, `device` |
# | [TF GraphDef](https://docs.ultralytics.com/integrations/tf-graphdef) | `pb` | `yolo11n.pb` | ❌ | `imgsz`, `batch`, `device` |
# | [TF Lite](https://docs.ultralytics.com/integrations/tflite) | `tflite` | `yolo11n.tflite` | ✅ | `imgsz`, `batch`, `half`, `int8`, `nms`, `fraction`, `device`, `data` |
# | [TF Edge TPU](https://docs.ultralytics.com/integrations/edge-tpu) | `edgetpu` | `yolo11n_edgetpu.tflite` | ✅ | `imgsz`, `device` |
# | [TF.js](https://docs.ultralytics.com/integrations/tfjs) | `tfjs` | `yolo11n_web_model/` | ✅ | `imgsz`, `batch`, `half`, `int8`, `nms`, `device` |
# | [PaddlePaddle](https://docs.ultralytics.com/integrations/paddlepaddle) | `paddle` | `yolo11n_paddle_model/` | ✅ | `imgsz`, `batch`, `device` |
# | [MNN](https://docs.ultralytics.com/integrations/mnn) | `mnn` | `yolo11n.mnn` | ✅ | `imgsz`, `batch`, `half`, `int8`, `device` |
# | [NCNN](https://docs.ultralytics.com/integrations/ncnn) | `ncnn` | `yolo11n_ncnn_model/` | ✅ | `imgsz`, `batch`, `half`, `device` |
# | [IMX500](https://docs.ultralytics.com/integrations/sony-imx500) | `imx` | `yolo11n_imx_model/` | ✅ | `imgsz`, `int8`, `fraction`, `device`, `data` |
# | [RKNN](https://docs.ultralytics.com/integrations/rockchip-rknn) | `rknn` | `yolo11n_rknn_model/` | ✅ | `imgsz`, `batch`, `name`, `device` || [ExecuTorch](https://docs.ultralytics.com/integrations/executorch) | `executorch` | `executorch_model/` | ✅ | `imgsz`, `device` |

# %%
# !yolo export model=yolo11n.pt format=torchscript
# Out:
# Ultralytics 8.3.187 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# PyTorch: starting from 'yolo11n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (5.4 MB)
#
# TorchScript: starting export with torch 2.8.0+cu126...
# TorchScript: export success ✅ 2.1s, saved as 'yolo11n.torchscript' (10.5 MB)
#
# Export complete (2.6s)
# Results saved to /content
# Predict:         yolo predict task=detect model=yolo11n.torchscript imgsz=640
# Validate:        yolo val task=detect model=yolo11n.torchscript imgsz=640 data=/usr/src/ultralytics/ultralytics/cfg/datasets/coco.yaml
# Visualize:       https://netron.app
# 💡 Learn more at https://docs.ultralytics.com/modes/export

# %% [markdown]
# # 5. Python Usage
#
# YOLO11 was reimagined using Python-first principles for the most seamless Python YOLO experience yet. YOLO11 models can be loaded from a trained checkpoint or created from scratch. Then methods are used to train, val, predict, and export the model. See detailed Python usage examples in the [YOLO11 Python Docs](https://docs.ultralytics.com/usage/python/).

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolo11n.yaml')  # build a new model from scratch
model = YOLO('yolo11n.pt')  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data='coco8.yaml', epochs=3)  # train the model
results = model.val()  # evaluate model performance on the validation set
results = model('https://ultralytics.com/images/bus.jpg')  # predict on an image
results = model.export(format='onnx')  # export the model to ONNX format

# %% [markdown]
# # 6. Tasks
#
# YOLO11 can train, val, predict and export models for the most common tasks in vision AI: [Detect](https://docs.ultralytics.com/tasks/detect/), [Segment](https://docs.ultralytics.com/tasks/segment/), [Classify](https://docs.ultralytics.com/tasks/classify/) and [Pose](https://docs.ultralytics.com/tasks/pose/). See [YOLO11 Tasks Docs](https://docs.ultralytics.com/tasks/) for more information.
#
# <br><img width="1024" src="https://raw.githubusercontent.com/ultralytics/assets/main/im/banner-tasks.png">

# %% [markdown]
# ## 1. Detection
#
# YOLO11 _detection_ models have no suffix and are the default YOLO11 models, i.e. `yolo11n.pt` and are pretrained on COCO. See [Detection Docs](https://docs.ultralytics.com/tasks/detect/) for full details.

# %%
# Load YOLO11n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo11n.pt')  # load a pretrained YOLO detection model
model.train(data='coco8.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 2. Segmentation
#
# YOLO11 _segmentation_ models use the `-seg` suffix, i.e. `yolo11n-seg.pt` and are pretrained on COCO. See [Segmentation Docs](https://docs.ultralytics.com/tasks/segment/) for full details.

# %%
# Load YOLO11n-seg, train it on COCO128-seg for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo11n-seg.pt')  # load a pretrained YOLO segmentation model
model.train(data='coco8-seg.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 3. Classification
#
# YOLO11 _classification_ models use the `-cls` suffix, i.e. `yolo11n-cls.pt` and are pretrained on ImageNet. See [Classification Docs](https://docs.ultralytics.com/tasks/classify/) for full details.

# %%
# Load YOLO11n-cls, train it on mnist160 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo11n-cls.pt')  # load a pretrained YOLO classification model
model.train(data='mnist160', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 4. Pose
#
# YOLO11 _pose_ models use the `-pose` suffix, i.e. `yolo11n-pose.pt` and are pretrained on COCO Keypoints. See [Pose Docs](https://docs.ultralytics.com/tasks/pose/) for full details.

# %%
# Load YOLO11n-pose, train it on COCO8-pose for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo11n-pose.pt')  # load a pretrained YOLO pose model
model.train(data='coco8-pose.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 4. Oriented Bounding Boxes (OBB)
#
# YOLO11 _OBB_ models use the `-obb` suffix, i.e. `yolo11n-obb.pt` and are pretrained on the DOTA dataset. See [OBB Docs](https://docs.ultralytics.com/tasks/obb/) for full details.

# %%
# Load YOLO11n-obb, train it on DOTA8 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo11n-obb.pt')  # load a pretrained YOLO OBB model
model.train(data='dota8.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/boats.jpg')  # predict on an image

# %% [markdown]
# # Appendix
#
# Additional content below.

# %%
# Pip install from source
# !uv pip install git+https://github.com/ultralytics/ultralytics@main

# %%
# Git clone and run tests on 'main' branch
# !git clone https://github.com/ultralytics/ultralytics -b main
# !uv pip install -qe ultralytics

# %%
# Run tests (Git clone only)
# !pytest ultralytics/tests

# %%
# Validate multiple models
for x in 'nsmlx':
  # !yolo val model=yolo11{x}.pt data=coco.yaml

# %% [markdown]
# # Task
# The "Missing image" messages are not indicative of an error in the provided code. They appear because some image files referenced in the TACO dataset's `annotations.json` are not present in the downloaded `tacotrashdataset/data` directory. The script correctly handles this by skipping those annotations for which the corresponding image file is missing.
#
# If you intend to use all annotations, you might need to:
# 1.  **Verify the integrity of the downloaded TACO dataset**: Ensure that the Kaggle dataset "kneroma/tacotrashdataset" you downloaded is complete and all referenced image files are present.
# 2.  **Manually download missing images**: If there are specific images crucial for your task, you might need to locate and download them separately if they exist elsewhere.

# %% [markdown]
# ## explain_missing_images
#
# ### Subtask:
# Explain that the 'Missing image' messages are due to images being absent from the downloaded TACO dataset, not a code error. The script correctly handles this by skipping them.

# %% [markdown]
# The 'Missing image' messages you observed in the previous output are not an error in the code's logic. They indicate that some image files referenced in the TACO dataset's 'annotations.json' are not actually present in the '/kaggle/input/tacotrashdataset/data' directory after downloading the dataset from KaggleHub. The script was designed to handle this by skipping the annotations associated with these missing images, allowing the conversion process to continue without crashing.

# %% [markdown]
# ## propose_dataset_integrity_check
#
# ### Subtask:
# Suggest that the user might need to verify the integrity of the downloaded TACO dataset or ensure all necessary image files are present if they expect all annotations to have corresponding images.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The 'Missing image' messages observed in the previous output are not indicative of an error in the provided code. Instead, they signify that certain image files referenced in the TACO dataset's `annotations.json` file are not present in the `/kaggle/input/tacotrashdataset/data` directory. The script is designed to handle this situation by skipping the annotations associated with these missing images, thus preventing crashes and allowing the conversion process to continue.
#
# ### Data Analysis Key Findings
# *   The 'Missing image' messages are a result of discrepancies between the `annotations.json` file and the actual image files available in the downloaded dataset.
# *   The script correctly identifies and skips annotations for which corresponding image files are absent, demonstrating robust error handling.
#
# ### Insights or Next Steps
# *   If the goal is to utilize all annotations, it is crucial to verify the integrity and completeness of the downloaded TACO dataset from Kaggle to ensure all referenced image files are present.
# *   Alternatively, if specific missing images are essential, they may need to be located and downloaded manually from external sources.
